# %% [markdown]
# <a href="https://colab.research.google.com/github/rushimhaisane8830/DS/blob/main/fetch_california_housing_DecisionTreeRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
x, y = fetch_california_housing(return_X_y=True)

# %%
x[0]
# Out:
# array([   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#         322.        ,    2.55555556,   37.88      , -122.23      ])

# %%
y[0]
# Out:
# np.float64(4.526)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtl = DecisionTreeRegressor(min_samples_split=8)

# %%
dtl.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(min_samples_split=5)

# %%
y_pred = dtl.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6337735537082083

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.47990642329002253

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.4470266046915375

# %%
y_pred
# Out:
# array([0.4155 , 1.203  , 5.00001, ..., 5.00001, 0.65075, 2.1215 ])

# %%
val = [[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
        322.        ,    2.55555556,   37.88      , -122.23      ]]

# %%
pred = dtl.predict(val)

# %%
pred
# Out:
# array([4.2145])
