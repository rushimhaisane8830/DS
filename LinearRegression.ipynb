# %% [markdown]
# <a href="https://colab.research.google.com/github/rushimhaisane8830/DS/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data ={
    "cgpa":[4.5,6.1,7.5,8.4,9.4,6.4,7.3],
    "package":[2.5,4.3,6.4,7.3,10.4,4.6,5.7]

}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    cgpa  package
# 0   4.5      2.5
# 1   6.1      4.3
# 2   7.5      6.4
# 3   8.4      7.3
# 4   9.4     10.4
# 5   6.4      4.6
# 6   7.3      5.7

# %%
x = df.iloc[:,0:1]
y =df.iloc[:,-1]

# %%
x_train, x_test ,y_train, y_test = train_test_split(x , y , test_size=0.2, random_state=1)

# %%
y
# Out:
# 0     2.5
# 1     4.3
# 2     6.4
# 3     7.3
# 4    10.4
# 5     4.6
# 6     5.7
# Name: package, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["cgpa"], df["package"])
plt.plot(x_train, lr.predict(x_train), color="red")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()

# %%
from sklearn.metrics import accuracy_score
